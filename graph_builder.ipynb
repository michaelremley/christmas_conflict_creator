# %% [markdown]
# # Convert CSV to a graph

# %%
import networkx as nx
import pandas as pd

# %%
def import_csv(filename):
    return pd.read_csv(filename)



data = import_csv("Survey.csv")
data.head(3)
# Out:
#                    Timestamp What is your name/identifier?  \
# 0  2020/12/02 3:05:20 PM EST                         Ghost
# 1  2020/12/02 3:05:36 PM EST                        Zombie
# 2  2020/12/02 3:05:57 PM EST                        Turkey
#
#   Is a hot dog a sandwich? What shape is the earth?  \
# 0                       No                     Flat
# 1                      Yes                     Flat
# 2                       No                   Torrus
#
#   Is a Klein bottle with filling a ravioli?  \
# 0                                        No
# 1                                        No
# 2                                        No
#
#   Is it possible for one person to produce both a ghost and a zombie when they die?  \
# 0                                                 No
# 1                                                Yes
# 2                                                Yes
#
#   Is spam good? Should pineapple go on pizza?
# 0           Yes                           Yes
# 1           Yes                            No
# 2           Yes                           Yes

# %%
for i, j in data.iterrows(): 
    print(i, j)
# Out:
# 0 Timestamp                                                                            2020/12/02 3:05:20 PM EST
# What is your name/identifier?                                                                            Ghost
# Is a hot dog a sandwich?                                                                                    No
# What shape is the earth?                                                                                  Flat
# Is a Klein bottle with filling a ravioli?                                                                   No
# Is it possible for one person to produce both a ghost and a zombie when they die?                           No
# Is spam good?                                                                                              Yes
# Should pineapple go on pizza?                                                                              Yes
# Name: 0, dtype: object
# 1 Timestamp                                                                            2020/12/02 3:05:36 PM EST
# What is your name/identifier?                                                                           Zombie
# Is a hot dog a sandwich?                                                                                   Yes
# What shape is the earth?                                                                                  Flat
# Is a Klein bottle with filling a ravioli?                                                                   No
# Is it possible for one person to produce both a ghost and a zombie when they die?                          Yes
# Is spam good?                                                                                              Yes
# Should pineapple go on pizza?                                                                               No
# Name: 1, dtype: object
# 2 Timestamp                                                                            2020/12/02 3:05:57 PM EST
# What is your name/identifier?                                                                           Turkey
# Is a hot dog a sandwich?                                                                                    No
# What shape is the earth?                                                                                Torrus
# Is a Klein bottle with filling a ravioli?                                                                   No
# Is it possible for one person to produce both a ghost and a zombie when they die?                          Yes
# Is spam good?                                                                                              Yes
# Should pineapple go on pizza?                                                                              Yes
# Name: 2, dtype: object
# 3 Timestamp                                                                            2020/12/02 3:06:23 PM EST
# What is your name/identifier?                                                                      Santa Claus
# Is a hot dog a sandwich?                                                                                   Yes
# What shape is the earth?                                                                                  Flat
# Is a Klein bottle with filling a ravioli?                                                                   No
# Is it possible for one person to produce both a ghost and a zombie when they die?                           No
# Is spam good?                                                                                               No
# Should pineapple go on pizza?                                                                              Yes
# Name: 3, dtype: object
# 4 Timestamp                                                                            2020/12/02 3:07:05 PM EST
# What is your name/identifier?                                                                              Cat
# Is a hot dog a sandwich?                                                                                   Yes
# What shape is the earth?                                                                                Torrus
# Is a Klein bottle with filling a ravioli?                                                                  Yes
# Is it possible for one person to produce both a ghost and a zombie when they die?                          Yes
# Is spam good?                                                                                              Yes
# Should pineapple go on pizza?                                                                              Yes
# Name: 4, dtype: object
# 5 Timestamp                                                                            2020/12/02 3:07:31 PM EST
# What is your name/identifier?                                                                           Cactus
# Is a hot dog a sandwich?                                                                                    No
# What shape is the earth?                                                                                Torrus
# Is a Klein bottle with filling a ravioli?                                                                  Yes
# Is it possible for one person to produce both a ghost and a zombie when they die?                          Yes
# Is spam good?                                                                                               No
# Should pineapple go on pizza?                                                                               No
# Name: 5, dtype: object

# %%
# DataFrame.items
# Iterate over (column name, Series) pairs.
for i, j in data.iteritems(): 
    print(i, j)
# Out:
# Timestamp 0    2020/12/02 3:05:20 PM EST
# 1    2020/12/02 3:05:36 PM EST
# 2    2020/12/02 3:05:57 PM EST
# 3    2020/12/02 3:06:23 PM EST
# 4    2020/12/02 3:07:05 PM EST
# 5    2020/12/02 3:07:31 PM EST
# Name: Timestamp, dtype: object
# What is your name/identifier? 0          Ghost
# 1         Zombie
# 2         Turkey
# 3    Santa Claus
# 4            Cat
# 5         Cactus
# Name: What is your name/identifier?, dtype: object
# Is a hot dog a sandwich? 0     No
# 1    Yes
# 2     No
# 3    Yes
# 4    Yes
# 5     No
# Name: Is a hot dog a sandwich?, dtype: object
# What shape is the earth? 0      Flat
# 1      Flat
# 2    Torrus
# 3      Flat
# 4    Torrus
# 5    Torrus
# Name: What shape is the earth?, dtype: object
# Is a Klein bottle with filling a ravioli? 0     No
# 1     No
# 2     No
# 3     No
# 4    Yes
# 5    Yes
# Name: Is a Klein bottle with filling a ravioli?, dtype: object
# Is it possible for one person to produce both a ghost and a zombie when they die? 0     No
# 1    Yes
# 2    Yes
# 3     No
# 4    Yes
# 5    Yes
# Name: Is it possible for one person to produce both a ghost and a zombie when they die?, dtype: object
# Is spam good? 0    Yes
# 1    Yes
# 2    Yes
# 3     No
# 4    Yes
# 5     No
# Name: Is spam good?, dtype: object
# Should pineapple go on pizza? 0    Yes
# 1     No
# 2    Yes
# 3    Yes
# 4    Yes
# 5     No
# Name: Should pineapple go on pizza?, dtype: object

# %%
for i in data.iteritems():  # for column
    print(i)
# Out:
# ('Timestamp', 0    2020/12/02 3:05:20 PM EST
# 1    2020/12/02 3:05:36 PM EST
# 2    2020/12/02 3:05:57 PM EST
# 3    2020/12/02 3:06:23 PM EST
# 4    2020/12/02 3:07:05 PM EST
# 5    2020/12/02 3:07:31 PM EST
# Name: Timestamp, dtype: object)
# ('What is your name/identifier?', 0          Ghost
# 1         Zombie
# 2         Turkey
# 3    Santa Claus
# 4            Cat
# 5         Cactus
# Name: What is your name/identifier?, dtype: object)
# ('Is a hot dog a sandwich?', 0     No
# 1    Yes
# 2     No
# 3    Yes
# 4    Yes
# 5     No
# Name: Is a hot dog a sandwich?, dtype: object)
# ('What shape is the earth?', 0      Flat
# 1      Flat
# 2    Torrus
# 3      Flat
# 4    Torrus
# 5    Torrus
# Name: What shape is the earth?, dtype: object)
# ('Is a Klein bottle with filling a ravioli?', 0     No
# 1     No
# 2     No
# 3     No
# 4    Yes
# 5    Yes
# Name: Is a Klein bottle with filling a ravioli?, dtype: object)
# ('Is it possible for one person to produce both a ghost and a zombie when they die?', 0     No
# 1    Yes
# 2    Yes
# 3     No
# 4    Yes
# 5    Yes
# Name: Is it possible for one person to produce both a ghost and a zombie when they die?, dtype: object)
# ('Is spam good?', 0    Yes
# 1    Yes
# 2    Yes
# 3     No
# 4    Yes
# 5     No
# Name: Is spam good?, dtype: object)
# ('Should pineapple go on pizza?', 0    Yes
# 1     No
# 2    Yes
# 3    Yes
# 4    Yes
# 5     No
# Name: Should pineapple go on pizza?, dtype: object)
